# %%
import matplotlib.pyplot as plt

# %%
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18,6))

# %%
# Monthly average precipitation
boulder_monthly_precip = [0.70, 0.75, 1.85, 2.93, 3.05, 2.02, 
                          1.93, 1.62, 1.84, 1.31, 1.39, 0.84]

# Month names for plotting
months = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", 
          "Aug", "Sept", "Oct", "Nov", "Dec"]

# %%
# Define plot space
fig, ax = plt.subplots(figsize=(10, 6))

# Define x and y axes
ax.scatter(months, 
        boulder_monthly_precip,
        marker='.')

# Set plot title and axes labels
ax.set(title = "Average Monthly Precipitation\nBoulder, CO",
       xlabel = "Month",
       ylabel = "Precipitation\n(inches)")

plt.setp(ax.get_xticklabels(), rotation = 45)

plt.show()

# %%
! pip install earthpy
# Out:
# Collecting earthpy
#   Downloading earthpy-0.9.4-py3-none-any.whl (1.4 MB)
# Collecting rasterio
#   Downloading rasterio-1.3.2-cp39-cp39-win_amd64.whl (22.2 MB)
# Requirement already satisfied: scikit-image in c:\users\mmart\anaconda3\lib\site-packages (from earthpy) (0.18.3)
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\mmart\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_eae66ef2bb834d09915964e80e3ee6ae\\setup.py'"'"'; __file__='"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_eae66ef2bb834d09915964e80e3ee6ae\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\mmart\AppData\Local\Temp\pip-pip-egg-info-k4334rcv'
#          cwd: C:\Users\mmart\AppData\Local\Temp\pip-install-pxmovfy9\fiona_eae66ef2bb834d09915964e80e3ee6ae\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/67/5c/4e028e84a1f0cb3f8a994217cf2366360ca984dfc1433f6171de527d0dca/Fiona-1.8.21.tar.gz#sha256=3a0edca2a7a070db405d71187214a43d2333a57b4097544a3fcc282066a58bfc (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\mmart\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_52475691582247adb125d95b72124df8\\setup.py'"'"'; __file__='"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_52475691582247adb125d95b72124df8\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\mmart\AppData\Local\Temp\pip-pip-egg-info-5_ndskim'
#          cwd: C:\Users\mmart\AppData\Local\Temp\pip-install-pxmovfy9\fiona_52475691582247adb125d95b72124df8\
# Collecting geopandas
#   Downloading geopandas-0.11.1-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: requests in c:\users\mmart\anaconda3\lib\site-packages (from earthpy) (2.26.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\mmart\anaconda3\lib\site-packages (from earthpy) (1.20.3)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\mmart\anaconda3\lib\site-packages (from earthpy) (3.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mmart\anaconda3\lib\site-packages (from matplotlib>=2.0.0->earthpy) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mmart\anaconda3\lib\site-packages (from matplotlib>=2.0.0->earthpy) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mmart\anaconda3\lib\site-packages (from matplotlib>=2.0.0->earthpy) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\mmart\anaconda3\lib\site-packages (from matplotlib>=2.0.0->earthpy) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mmart\anaconda3\lib\site-packages (from matplotlib>=2.0.0->earthpy) (8.4.0)
# Requirement already satisfied: six in c:\users\mmart\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.0.0->earthpy) (1.16.0)
# Requirement already satisfied: packaging in c:\users\mmart\anaconda3\lib\site-packages (from geopandas->earthpy) (21.0)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\mmart\anaconda3\lib\site-packages (from geopandas->earthpy) (1.3.4)
# Collecting pyproj>=2.6.1.post1
#   Downloading pyproj-3.3.1-cp39-cp39-win_amd64.whl (6.4 MB)
# Collecting shapely<2,>=1.7
#   Downloading Shapely-1.8.4-cp39-cp39-win_amd64.whl (1.3 MB)
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.21.tar.gz (1.0 MB)
#   Downloading Fiona-1.8.20.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.19.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.18.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.17.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.16.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.15.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.14.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.13.post1.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.13.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.12.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.11.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.10.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.9.post2.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.9.post1.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.9.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.8.tar.gz (1.7 MB)
#   Downloading Fiona-1.8.7.tar.gz (1.7 MB)
#   Downloading Fiona-1.8.6.tar.gz (1.7 MB)
#   Downloading Fiona-1.8.5.tar.gz (1.7 MB)
#   Downloading Fiona-1.8.4.tar.gz (1.1 MB)
#   Downloading Fiona-1.8.3.tar.gz (1.1 MB)
#   Downloading Fiona-1.8.2.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.1.tar.gz (1.1 MB)
#   Downloading Fiona-1.8.0.tar.gz (1.4 MB)
# Collecting geopandas
#   Downloading geopandas-0.11.0-py3-none-any.whl (1.0 MB)
#   Downloading geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
#   Downloading geopandas-0.10.1-py2.py3-none-any.whl (1.0 MB)
#   Downloading geopandas-0.10.0-py2.py3-none-any.whl (1.0 MB)
#   Downloading geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#   Downloading geopandas-0.8.2-py2.py3-none-any.whl (962 kB)
# Collecting fiona
#   Downloading Fiona-1.7.13.tar.gz (731 kB)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mmart\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas->earthpy) (2021.3)
# Requirement already satisfied: certifi in c:\users\mmart\anaconda3\lib\site-packages (from pyproj>=2.6.1.post1->geopandas->earthpy) (2021.10.8)
# Collecting cligj>=0.4
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: click>=4.0 in c:\users\mmart\anaconda3\lib\site-packages (from cligj>=0.4->fiona->geopandas->earthpy) (8.0.3)
# Requirement already satisfied: colorama in c:\users\mmart\anaconda3\lib\site-packages (from click>=4.0->cligj>=0.4->fiona->geopandas->earthpy) (0.4.4)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting affine
#   Downloading affine-2.3.1-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: attrs in c:\users\mmart\anaconda3\lib\site-packages (from rasterio->earthpy) (21.2.0)
# Requirement already satisfied: setuptools in c:\users\mmart\anaconda3\lib\site-packages (from rasterio->earthpy) (58.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mmart\anaconda3\lib\site-packages (from requests->earthpy) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mmart\anaconda3\lib\site-packages (from requests->earthpy) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mmart\anaconda3\lib\site-packages (from requests->earthpy) (2.0.4)
# Requirement already satisfied: scipy>=1.0.1 in c:\users\mmart\anaconda3\lib\site-packages (from scikit-image->earthpy) (1.7.1)
# Requirement already satisfied: networkx>=2.0 in c:\users\mmart\anaconda3\lib\site-packages (from scikit-image->earthpy) (2.6.3)
# Requirement already satisfied: imageio>=2.3.0 in c:\users\mmart\anaconda3\lib\site-packages (from scikit-image->earthpy) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\mmart\anaconda3\lib\site-packages (from scikit-image->earthpy) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users

#          cwd: C:\Users\mmart\AppData\Local\Temp\pip-install-pxmovfy9\fiona_69acc6bda2b34e3e8b66efa2cf7ff7df\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3a/16/84960540e9fce61d767fd2f0f1d95f4c63e99ab5d8fddc308e8b51b059b8/Fiona-1.8.4.tar.gz#sha256=aec9ab2e3513c9503ec123b1a8573bee55fc6a66e2ac07088c3376bf6738a424 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\mmart\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_00025f8d7344436eb0cff51c64065ed3\\setup.py'"'"'; __file__='"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_00025f8d7344436eb0cff51c64065ed3\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\mmart\AppData\Local\Temp\pip-pip-egg-info-zlbdjfns'
#          cwd: C:\Users\mmart\AppData\Local\Temp\pip-install-pxmovfy9\fiona_00025f8d7344436eb0cff51c64065ed3\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/46/d1/fcdb32513a03abfde0d97fd9782ce0f8cc0540fa6c6ce783e87b94064964/Fiona-1.8.3.tar.gz#sha256=3e831100a23c3b6cd32b98baf0c9e2119d909b44a5cf4533d3625f61dcf2d2b1 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\mmart\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_0c873f0e0cdf4f5d87b827036045c8ac\\setup.py'"'"'; __file__='"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_0c873f0e0cdf4f5d87b827036045c8ac\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\mmart\AppData\Local\Temp\pip-pip-egg-info-jhhgrpv7'
#          cwd: C:\Users\mmart\AppData\Local\Temp\pip-install-pxmovfy9\fiona_0c873f0e0cdf4f5d87b827036045c8ac\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/25/50/0466d5d83e1859c5ca38351ee932d64cc5635f9d4dad522879e58f4b0018/Fiona-1.8.2.tar.gz#sha256=4c6419b7ac29136708029f6a44b4ccd458735a4d241016c7b1bab41685c08d8f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\mmart\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_fbb940d9d7de43c5b7afca1967daf547\\setup.py'"'"'; __file__='"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_fbb940d9d7de43c5b7afca1967daf547\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\mmart\AppData\Local\Temp\pip-pip-egg-info-7apn7t99'
#          cwd: C:\Users\mmart\AppData\Local\Temp\pip-install-pxmovfy9\fiona_fbb940d9d7de43c5b7afca1967daf547\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3e/5f/0c6704efeea2ff3fba7f54cc6ec38070157f21bc1cffa7bdfa7c9f6b8f7a/Fiona-1.8.1.tar.gz#sha256=4c34bb4c5cd788aaf14e5484c3b7de407b1a8a7c7b2d29bbb2e8b37931e83b8d (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\mmart\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_08b3e352baa2402db5130a48c3d09870\\setup.py'"'"'; __file__='"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_08b3e352baa2402db5130a48c3d09870\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\mmart\AppData\Local\Temp\pip-pip-egg-info-_b5x_3zo'
#          cwd: C:\Users\mmart\AppData\Local\Temp\pip-install-pxmovfy9\fiona_08b3e352baa2402db5130a48c3d09870\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/2a/bd/c1efc2680f338e5941121c776d6323af6b9698ac739e22ba523cee348a7f/Fiona-1.8.0.tar.gz#sha256=20141a9ece06daa7bb4333fba640c2fe39a49f8aca5492d1da8595d41e91844a (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\mmart\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_bcd28e41f4f942eab2e8f024c3b07d52\\setup.py'"'"'; __file__='"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_bcd28e41f4f942eab2e8f024c3b07d52\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\mmart\AppData\Local\Temp\pip-wheel-hgtcpzvn'
#        cwd: C:\Users\mmart\AppData\Local\Temp\pip-install-pxmovfy9\fiona_bcd28e41f4f942eab2e8f024c3b07d52\
#   Complete output (48 lines):
#   C:\Users\mmart\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'metadata_version'
#     warnings.warn(msg)
#   C:\Users\mmart\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_python'
#     warnings.warn(msg)
#   C:\Users\mmart\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_external'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\fiona
#   copying .\fiona\collection.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\compat.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\crs.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\drvsupport.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\errors.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\inspector.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\rfc3339.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\tool.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\transform.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\__init__.py -> build\lib.win-amd64-3.9\fiona
#   creating build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\bounds.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\calc.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\cat.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\collect.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\distrib.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\dump.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\env.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\filter.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\helpers.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\info.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\insp.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\load.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\ls.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\main.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\options.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\__init__.py -> build\lib.win-amd64-3.9\fiona\fio
#   running build_ext
#   building 'fiona._transform' extension
#   creating build\temp.win-amd64-3.9
#   creating build\temp.win-amd64-3.9\Release
#   creating build\temp.win-amd64-3.9\Release\fiona
#   C:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.32.31326\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -IC:\Users\mmart\anaconda3\include -IC:\Users\mmart\anaconda3\include -IC:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.32.31326\ATLMFC\include -IC:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.32.31326\include -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\cppwinrt /EHsc /Tpfiona/_transform.cpp /Fobuild\temp.win-amd64-3.9\Release\fiona/_transform.obj
#   _transform.cpp
#   fiona/_transform.cpp(606): fatal error C1083: No se puede abrir el archivo incluir: 'cpl_conv.h': No such file or directory
#   error: command 'C:\\Program Files\\Microsoft Visual Studio\\2022\\Community\\VC\\Tools\\MSVC\\14.32.31326\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#   ----------------------------------------
#   ERROR: Failed building wheel for fiona
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\mmart\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_bcd28e41f4f942eab2e8f024c3b07d52\\setup.py'"'"'; __file__='"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_bcd28e41f4f942eab2e8f024c3b07d52\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\mmart\AppData\Local\Temp\pip-record-bbh54ihr\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\mmart\anaconda3\Include\fiona'
#          cwd: C:\Users\mmart\AppData\Local\Temp\pip-install-pxmovfy9\fiona_bcd28e41f4f942eab2e8f024c3b07d52\
#     Complete output (18 lines):
#     C:\Users\mmart\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'metadata_version'
#       warnings.warn(msg)
#     C:\Users\mmart\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_python'
#       warnings.warn(msg)
#     C:\Users\mmart\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_external'
#       warnings.warn(msg)
#     running install
#     running build
#     running build_py
#     running build_ext
#     building 'fiona._transform' extension
#     creating build\temp.win-amd64-3.9
#     creating build\temp.win-amd64-3.9\Release
#     creating build\temp.win-amd64-3.9\Release\fiona
#     C:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.32.31326\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -IC:\Users\mmart\anaconda3\include -IC:\Users\mmart\anaconda3\include -IC:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.32.31326\ATLMFC\include -IC:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.32.31326\include -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\cppwinrt /EHsc /Tpfiona/_transform.cpp /Fobuild\temp.win-amd64-3.9\Release\fiona/_transform.obj
#     _transform.cpp
#     fiona/_transform.cpp(606): fatal error C1083: No se puede abrir el archivo incluir: 'cpl_conv.h': No such file or directory
#     error: command 'C:\\Program Files\\Microsoft Visual Studio\\2022\\Community\\VC\\Tools\\MSVC\\14.32.31326\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\mmart\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_bcd28e41f4f942eab2e8f024c3b07d52\\setup.py'"'"'; __file__='"'"'C:\\Users\\mmart\\AppData\\Local\\Temp\\pip-install-pxmovfy9\\fiona_bcd28e41f4f942eab2e8f024c3b07d52\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\mmart\AppData\Local\Temp\pip-record-bbh54ihr\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\mmart\anaconda3\Include\fiona' Check the logs for full command output.

# %%
# Import required python packages
import os
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
import seaborn as sns
import earthpy as et

# Date time conversion registration
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()


# Get the data
data = et.data.get_data('colorado-flood')

# Set working directory
os.chdir(os.path.join(et.io.HOME, 'earth-analytics', 'data'))

# Prettier plotting with seaborn
sns.set(font_scale=1.5)
# Ticks instead of whitegrid in order to demonstrate changes to plot ticks better
sns.set_style("ticks")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18688/1412680629.py in <module>
#       6 import matplotlib.dates as mdates
#       7 import seaborn as sns
# ----> 8 import earthpy as et
#       9
#      10 # Date time conversion registration
#
# ModuleNotFoundError: No module named 'earthpy'
