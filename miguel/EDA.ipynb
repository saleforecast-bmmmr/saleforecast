# %% [markdown]
# # EDA del dataset Sales Multistore completo preprocesado

# %% [markdown]
# ## 1. Importación de librerías y de datos

# %%
import pandas as pd
import numpy as np
from decimal import Decimal
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
import seaborn as sns
from collections import defaultdict
import math
import json


# Date time conversion registration
from pandas.plotting import register_matplotlib_converters

# %%
# Configuraciones de Pandas, Numpy, Decimal, etc.

# Pandas
pd.options.mode.chained_assignment = None

# Matplotlib
register_matplotlib_converters()

# Seaborn
sns.set(font_scale=1.5)
# sns.set(rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'}, font_scale=1.5)
sns.set_style("ticks")

# %%
pd_sales_multistore = pd.read_csv('sales_multistore_10_2019_04_2020_v2.csv')

# %% [markdown]
# ## 2. Análisis de la estructura

# %%
pd_sales_multistore.head(10)
# Out:
#                   event_time  product_id          category_id  \
# 0  2019-10-01 00:02:14+00:00     1004856  2053013555631882655
# 1  2019-10-01 00:04:37+00:00     1002532  2053013555631882655
# 2  2019-10-01 00:07:07+00:00    13800054  2053013557418656265
# 3  2019-10-01 00:09:26+00:00     4804055  2053013554658804075
# 4  2019-10-01 00:09:54+00:00     4804056  2053013554658804075
# 5  2019-10-01 00:10:08+00:00     1002524  2053013555631882655
# 6  2019-10-01 00:10:56+00:00     6200687  2053013552293216471
# 7  2019-10-01 00:12:14+00:00     4802036  2053013554658804075
# 8  2019-10-01 00:14:14+00:00     1004932  2053013555631882655
# 9  2019-10-01 02:19:10+00:00     1004246  2053013555631882655
#
#                        category_code    brand   price    user_id  \
# 0             electronics.smartphone  samsung  130.76  543272936
# 1             electronics.smartphone    apple  642.69  551377651
# 2          furniture.bathroom.toilet  santeri   54.42  555332717
# 3        electronics.audio.headphone    apple  189.91  524601178
# 4        electronics.audio.headphone    apple  161.98  551377651
# 5             electronics.smartphone    apple  515.67  524325294
# 6  appliances.environment.air_heater    oasis   28.03  548691404
# 7        electronics.audio.headphone    apple  171.56  533624186
# 8             electronics.smartphone     vivo  463.31  555083442
# 9             electronics.smartphone    apple  736.18  515246296
#
#                            user_session
# 0  8187d148-3c41-46d4-b0c0-9c08cd9dc564
# 1  3c80f0d6-e9ec-4181-8c5c-837a30be2d68
# 2  1dea3ee2-2ded-42e8-8e7a-4e2ad6ae942f
# 3  2af9b570-0942-4dcd-8f25-4d84fba82553
# 4  3c80f0d6-e9ec-4181-8c5c-837a30be2d68
# 5  0b74a829-f9d7-4654-b5b0-35bc9822c238
# 6  b67cdbcb-b073-4271-b365-803c6fce53b0
# 7  e5ac3caa-e6d5-4d6b-ae06-2c18cd9ca683
# 8  83d12d1a-5452-4fa0-abbb-d9f492f8b562
# 9  b7dbae4f-cad3-463e-89ce-41990cf48dea

# %%
pd_sales_multistore.shape
# Out:
# (5707926, 8)

# %%
pd_sales_multistore.dtypes
# Out:
# event_time        object
# product_id         int64
# category_id        int64
# category_code     object
# brand             object
# price            float64
# user_id            int64
# user_session      object
# dtype: object

# %%
pd_sales_multistore.columns
# Out:
# Index(['event_time', 'product_id', 'category_id', 'category_code', 'brand',
#        'price', 'user_id', 'user_session'],
#       dtype='object')

# %%
# Cambio el tipo de datos de algunas columnas
# Los tipos de datos más eficiente a efectos de manejo de memoria son los numéricos int
# Cambio a int las columnas que tienen valores numéricos, aunque no vaya a hacer operaciones
# con estos valores.
# Una excepción es 'price'. Quiero que tenga precisión decimal (no de float), pero
# curiosamente para convertir a este tipo hay que partir de string, no de float.
# Cambiar object por category cuando se trata de variables categóricas es más eficiente
# También cambio la variable 'event_time' a datetime, para poder hacer cálculos de fechas
pd_sales_multistore = pd_sales_multistore.astype({"product_id":'int32', "category_id":'int64', \
                                                   "category_code":'category', "brand":'category', \
                                                   "price":'string', "user_session":'string'})
pd_sales_multistore['event_time'] = pd.to_datetime(pd_sales_multistore['event_time'])

# %%
pd_sales_multistore.dtypes
# Out:
# event_time       datetime64[ns, UTC]
# product_id                     int32
# category_id                    int64
# category_code               category
# brand                       category
# price                         string
# user_id                        int64
# user_session                  string
# dtype: object

# %% [markdown]
# ### 2.1 Variables numéricas

# %%
# Valores únicos de cada variable numérica, ordenadas
pd_sales_multistore_unique = pd_sales_multistore.select_dtypes(include="number").nunique().sort_values()

# Ploteo con escala logarítmica en el eje y
pd_sales_multistore_unique.plot.bar(logy=True, figsize=(15, 4), title="Valores únicos por variable numérica")
plt.show()

# %% [markdown]
# Todo parece lógico: hay menos categorías (category_id) que productos (product_id) y más usuarios (user_id) que productos y categorías.

# %%
# referencias distintas que aparecen en el dataset
pd_sales_multistore['product_id'].nunique()
# Out:
# 96037

# %% [markdown]
# ### 2.2 Variables no numéricas

# %%
# Valores únicos de cada variable no numérica, ordenadas. 'price' aparece como variable no numérica,
# porque lo he convertido a string como paso previo para convertirlo en decimal.
pd_sales_multistore.describe(exclude="number", datetime_is_numeric=True)
# Out:
#                                  event_time             category_code  \
# count                               5707926                   5707926
# unique                                  NaN                       139
# top                                     NaN  construction.tools.light
# freq                                    NaN                   2309625
# mean    2020-01-23 02:08:21.779728640+00:00                       NaN
# min               2019-10-01 00:02:14+00:00                       NaN
# 25%        2019-12-10 12:09:34.500000+00:00                       NaN
# 50%               2020-01-27 16:41:30+00:00                       NaN
# 75%     2020-03-08 02:34:04.750000128+00:00                       NaN
# max               2020-04-30 23:59:36+00:00                       NaN
#
#           brand    price                          user_session
# count   5707926  5707926                               5707923
# unique     4081    67748                               4544395
# top     samsung   128.42  12ec3547-84f2-4eab-bd64-725ddc03dd5b
# freq    1563759    28090                                   403
# mean        NaN      NaN                                   NaN
# min         NaN      NaN                                   NaN
# 25%         NaN      NaN                                   NaN
# 50%         NaN      NaN                                   NaN
# 75%         NaN      NaN                                   NaN
# max         NaN      NaN                                   NaN

# %% [markdown]
# ## 3. Calidad de los datos

# %% [markdown]
# ### 3.1 Filas duplicadas

# %%
# Ignoramos el índice, que hace que las filas sean distintas
pd_sales_multistore[pd_sales_multistore.duplicated()]
# Out:
#                        event_time  product_id          category_id  \
# 3310    2019-10-01 06:41:39+00:00     1004856  2053013555631882655
# 9555    2019-10-01 12:42:40+00:00     1004767  2053013555631882655
# 49420   2019-10-04 07:20:16+00:00     5700758  2053013553970938175
# 67687   2019-10-05 05:34:08+00:00     1004856  2053013555631882655
# 79698   2019-10-05 16:37:05+00:00     1801690  2053013554415534427
# ...                           ...         ...                  ...
# 5297185 2020-04-16 17:00:09+00:00    24100688  2232732100954423843
# 5550832 2020-04-26 08:45:24+00:00     1002540  2232732093077520756
# 5642867 2020-04-29 04:16:34+00:00     8800895  2053013560530830019
# 5666683 2020-04-29 15:33:22+00:00     1005169  2232732093077520756
# 5666781 2020-04-29 15:36:26+00:00     1005169  2232732093077520756
#
#                         category_code    brand   price    user_id  \
# 3310           electronics.smartphone  samsung  130.76  555119233
# 9555           electronics.smartphone  samsung  254.19  512386086
# 49420         auto.accessories.player  pioneer   75.94  517161433
# 67687          electronics.smartphone  samsung  131.92  535394720
# 79698            electronics.video.tv  samsung  370.53  539724704
# ...                               ...      ...     ...        ...
# 5297185  appliances.personal.massager  kerasys    6.56  635946366
# 5550832      construction.tools.light    apple  409.78  515172019
# 5642867      electronics.camera.video       bq   19.79  643856840
# 5666683      construction.tools.light  samsung  180.42  648354166
# 5666781      construction.tools.light  samsung  180.42  648354166
#
#                                  user_session
# 3310     53ad00ec-2d13-491c-9743-504913ea238c
# 9555     4a1f199d-e77b-4ff7-8807-47b31c1b6aca
# 49420    80109315-6ff2-4b59-adec-f99cd75efb81
# 67687    af308845-2f01-43c0-a441-d70814450de6
# 79698    352cbf09-0d93-4086-9395-49605f75c59f
# ...                                       ...
# 5297185  252d0d1f-23d9-4a36-bafd-82416840a9d1
# 5550832  5e8a156d-c481-4017-a550-63d4ba6ecaf8
# 5642867  aa10f9d5-3275-4390-8b29-1e408b286f89
# 5666683  2927cd4d-3a2a-4853-be26-f5139eff973f
# 5666781  2927cd4d-3a2a-4853-be26-f5139eff973f
#
# [134205 rows x 8 columns]

# %% [markdown]
# ¡Son muchas filas duplicadas! Espero que no haya ningún error en mi comando. Hago una comprobación y utilizo para ello el valor 'user_session' de la fila 3310 de arriba.

# %%
# No me deja hacer una AND de la 'product_id' y la 'user_session'. Al parecer tiene que ser el mismo tipo
# de datos
pd_sales_multistore.loc[pd_sales_multistore['user_session'] == '53ad00ec-2d13-491c-9743-504913ea238c']
# Out:
#                     event_time  product_id          category_id  \
# 3309 2019-10-01 06:41:39+00:00     1004856  2053013555631882655
# 3310 2019-10-01 06:41:39+00:00     1004856  2053013555631882655
# 3334 2019-10-01 06:43:02+00:00     1004750  2053013555631882655
#
#                category_code    brand   price    user_id  \
# 3309  electronics.smartphone  samsung  130.76  555119233
# 3310  electronics.smartphone  samsung  130.76  555119233
# 3334  electronics.smartphone  samsung  203.35  555119233
#
#                               user_session
# 3309  53ad00ec-2d13-491c-9743-504913ea238c
# 3310  53ad00ec-2d13-491c-9743-504913ea238c
# 3334  53ad00ec-2d13-491c-9743-504913ea238c

# %% [markdown]
# ¡Realmente están duplicadas! Elimino las filas duplicadas.

# %%
pd_sales_multistore.drop_duplicates(inplace=True)
pd_sales_multistore.shape
# Out:
# (5573721, 8)

# %% [markdown]
# ### 3.2 Valores faltantes

# %% [markdown]
# Aunque ya se hizo una limpieza de valores faltantes durante el preprocesamiento de los archivos originales, no está de más hacer una nueva comprobación.

# %%
pd_sales_multistore.isna().sum()
# Out:
# event_time       0
# product_id       0
# category_id      0
# category_code    0
# brand            0
# price            0
# user_id          0
# user_session     3
# dtype: int64

# %%
pd_sales_multistore[pd_sales_multistore.isna().any(axis=1)]
# Out:
#                        event_time  product_id          category_id  \
# 5294675 2020-04-16 15:39:34+00:00     5000313  2232732102950912587
# 5370972 2020-04-18 19:37:11+00:00     1005098  2232732093077520756
# 5581259 2020-04-27 07:18:28+00:00     2800477  2232732091307524418
#
#                             category_code    brand   price    user_id  \
# 5294675         appliances.sewing_machine  brother  175.81  563939005
# 5370972          construction.tools.light  samsung  146.46  643633435
# 5581259  appliances.kitchen.refrigerators     beko  422.12  514665829
#
#         user_session
# 5294675         <NA>
# 5370972         <NA>
# 5581259         <NA>

# %%
# Eliminamos estas filas con nulos
pd_sales_multistore.dropna(inplace=True)

# %%
pd_sales_multistore[pd_sales_multistore.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [event_time, product_id, category_id, category_code, brand, price, user_id, user_session]
# Index: []

# %% [markdown]
# ### 3.3 Otro tipo de errores en los datos

# %%
# Estadística de variables categóricas
pd_sales_multistore.describe(include=['category'], datetime_is_numeric=True)
# Out:
#                    category_code    brand
# count                    5573718  5573718
# unique                       139     4081
# top     construction.tools.light  samsung
# freq                     2232975  1527193

# %%
# Hay fechas fuera de rango?
print('Fecha inicial: {}, Fecha final: {}'.format(pd_sales_multistore['event_time'].min(), pd_sales_multistore['event_time'].max()))
# Out:
# Fecha inicial: 2019-10-01 00:02:14+00:00, Fecha final: 2020-04-30 23:59:36+00:00

# %%
# Convierto los valores de 'price' a decimal
pd_sales_multistore['price'] = pd_sales_multistore['price'].apply(Decimal)
# pd_sales_multistore['price'] = pd_sales_multistore['price'].apply(lambda x: round(x, 2))

# %%
print('Precio más bajo: {}, Precio más alto: {}'.format(pd_sales_multistore['price'].min(), pd_sales_multistore['price'].max()))
# Out:
# Precio más bajo: 0.2, Precio más alto: 2574.07

# %% [markdown]
# Otro chequeo que podemos hacer de los precios es si siguen una evolución normal.
# Averiguo cuáles son las referencias más vendidas, para utilizar valores representativos

# %%
# La referencia '1004767' es de las más vendidas (ver en el apdo. 5.1). Cuál es su precio mínimo y máximo dentro de la serie temporal?
print('Precio mínimo: {}'.format(pd_sales_multistore[pd_sales_multistore['product_id'] == 1004767]['price'].min()))
print('Precio máximo: {}'.format(pd_sales_multistore[pd_sales_multistore['product_id'] == 1004767]['price'].max()))
# Out:
# Precio mínimo: 223.92
# Precio máximo: 308.89

# %%
# Es una diferencia considerable
print('Diferencia entre el precio más alto y el más bajo: {}%'.format( round((Decimal(308.89)-Decimal(223.92))/Decimal(223.92)*100,2)))
# Out:
# Diferencia entre el precio más alto y el más bajo: 37.95%

# %% [markdown]
# Ploteo la evolución del precio de esta referencia. El problema es que no puedo plotear un valor decimal. Tengo que convertirlo primero a float.

# %%
pd_sales_multistore_1004767 = pd_sales_multistore[pd_sales_multistore['product_id'] == 1004767]
pd_sales_multistore_1004767['price'] = pd_sales_multistore_1004767['price'].astype(float)

# %%
pd_sales_multistore_1004767_plot = pd_sales_multistore_1004767.set_index('event_time')['price'].resample('D').max().to_frame() \
.reset_index()
pd_sales_multistore_1004767_plot.plot(figsize=(18,10), x='event_time', y='price', c='red', marker='.', \
title='Evolución del precio de la product_id 1004767')
plt.show()

# %% [markdown]
# Las discontinuidades de la gráfica se deben a que hay días en que no se ha producido venta de la referencia analizada. Pero, aparte de esto, el precio de esta referencia pega unos bandazos enormes. **¿Por qué?**

# %%
# Otra de las referencias más vendidos: 1005115
pd_sales_multistore_1005115 = pd_sales_multistore[pd_sales_multistore['product_id'] == 1005115]
pd_sales_multistore_1005115['price'] = pd_sales_multistore_1005115['price'].astype(float)
pd_sales_multistore_1005115_plot = pd_sales_multistore_1005115.set_index('event_time')['price'].resample('D').max().to_frame() \
.reset_index()
pd_sales_multistore_1005115_plot.plot(figsize=(18,10), x='event_time', y='price', c='darkblue', alpha=0.5, marker='.', \
title='Evolución del precio de la product_id 1005115')
plt.show()

# %% [markdown]
# ¡También pega unos bandazos enormes! Vamos a averiguar por qué.

# %%
# Trato de averiguar un máximo común divisor de los precios de esta product_id, por si los precios que
# aparecen fuera múltiplos de un precio unitario, con lo cual cambiaría todo el planteamiento del 
# análisis, porque cada entrada del dataframe no se referiría ya a 1 unidad vendida.
np.gcd.reduce(pd_sales_multistore_1005115['price'].astype('int').to_numpy())
# Out:
# 1

# %% [markdown]
# El MCD es 1, con lo cual NO hay MCD y entiendo que son precios unitarios. En caso de utilizar estos precios
# habría que decir qué hacemos con ellos para "estabilizarlos" (aplicar la media o la mediana).

# %% [markdown]
# ## 4. Parseado de categorías

# %%
pd_categories = pd_sales_multistore.drop_duplicates('category_code', keep='first')[['category_code', 'category_id']]
print(pd_categories.shape)
pd_categories.head(10)
# Out:
# (139, 2)
#                         category_code          category_id
# 0              electronics.smartphone  2053013555631882655
# 2           furniture.bathroom.toilet  2053013557418656265
# 3         electronics.audio.headphone  2053013554658804075
# 6   appliances.environment.air_heater  2053013552293216471
# 12     auto.accessories.videoregister  2053013560899928785
# 18                 computers.notebook  2053013558920217191
# 19      computers.peripherals.printer  2053013552955916539
# 20                 electronics.clocks  2053013553341792533
# 24                      apparel.shoes  2100064855133258156
# 35           computers.components.hdd  2053013554222596431

# %%
pd_categories.to_csv('categories.csv')

# %%
def crea_dict():
    return defaultdict(crea_dict)

categorias = crea_dict()

def dict_insert(key, value):
    d = categorias

    keys = key.split(".")
    for subkey in keys:
        d = d[subkey]
    d[keys[-1]] = value

# %%
pd_categories.apply(lambda x: dict_insert(x['category_code'], x['category_id']), axis=1)
categorias_json = json.dumps(categorias, indent=4)

# Guardamos el diccionario como JSON para poder utilizarlo posteriormente, p. ej. en Flask
with open('categorias.json', 'w') as outfile:
    outfile.write(categorias_json)

# %% [markdown]
# ## 5. Diversos rankings generales

# %% [markdown]
# ### 5.1 Referencias más vendidas

# %%
# Dataset ordenado por número de unidades vendidas
pd_sales_multistore[['product_id', 'user_session']].groupby(['product_id']).count(). \
sort_values(by=['user_session'], ascending=False).rename(columns={'user_session': 'units_sold_per_product_id'}).head(10)
# Comando alternativo
# pd_sales_multistore.value_counts(subset=['product_id'])
# Out:
#             units_sold_per_product_id
# product_id
# 1004767                        172598
# 1005115                        154301
# 1005100                        142075
# 1004856                        137999
# 4804056                        119640
# 1002544                        106498
# 1005212                         91083
# 1005160                         69756
# 1005105                         64030
# 1004249                         59860

# %%
# Evolución de las ventas de una referencia a lo largo del periodo observado
# Referencia n.º 1004767
pd_sales_multistore_1004767 = pd_sales_multistore[pd_sales_multistore['product_id'] == 1004767].set_index('event_time')['user_session'] \
.resample('D').count().to_frame().reset_index()

sns.set(font_scale=1.2)
fig, ax = plt.subplots(figsize=(18, 9))
ax.plot(pd_sales_multistore_1004767['event_time'],
        pd_sales_multistore_1004767['user_session'],
        '-o',
        color='magenta')
ax.set(xlabel="Fecha", ylabel="Unidades vendidas",
       title="Evolución de las unidades vendidas de la referencia 1004767")

ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter("%d-%m-%y"))

plt.show()

# %% [markdown]
# ### 5.2 Marcas más vendidas

# %%
# Dataset ordenado por número de unidades vendidas por marca
pd_sales_multistore[['brand', 'user_session']].groupby(['brand']).count(). \
sort_values(by=['user_session'], ascending=False).rename(columns={'user_session': 'units_sold_per_brand'}).head(10)
# Comando alternativo
# _sales_multistore.value_counts(subset=['brand'])
# Out:
#          units_sold_per_brand
# brand
# samsung               1527193
# apple                 1216172
# xiaomi                 506110
# huawei                 221154
# oppo                   116500
# lg                      87271
# lucente                 78721
# sony                    62378
# acer                    60265
# lenovo                  56033

# %%
# Evolución de las ventas de una marca a lo largo del periodo observado
# Marca: Apple
pd_sales_multistore_apple = pd_sales_multistore[pd_sales_multistore['brand'] == 'apple'].set_index('event_time')['user_session'] \
.resample('D').count().to_frame().reset_index()

sns.set(font_scale=1.2)
fig, ax = plt.subplots(figsize=(18, 9))
ax.plot(pd_sales_multistore_apple['event_time'],
        pd_sales_multistore_apple['user_session'],
        '-o',
        color='green')
ax.set(xlabel="Fecha", ylabel="Unidades vendidas",
       title="Evolución de las unidades vendidas de la marca Apple")

ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter("%d-%m-%y"))

plt.show()

# %% [markdown]
# ### 5.3 Productos más vendidos, por marca

# %%
# Dataset ordenado por número de unidades vendidas por producto y marca marca
pd_sales_multistore[['product_id', 'brand', 'user_session']].groupby(['brand', 'product_id'], observed=True)['user_session'] \
.count().to_frame().sort_values(by=['brand', 'user_session'], ascending=[True, False]).rename(columns={'user_session': 'units_sold_per_prod_id_brand'}).head(100)
# Out:
#                    units_sold_per_prod_id_brand
# brand  product_id
# a-case 100014125                            332
#        100014007                            231
#        100118021                            164
#        100118024                            134
#        18001338                             126
# ...                                         ...
#        18001415                               2
#        18001574                               2
#        100008067                              2
#        100008106                              2
#        100011802                              2
#
# [100 rows x 1 columns]

# %% [markdown]
# ### 5.4 Clientes más compradores (por número de referencias compradas en total)

# %%
# Dataset ordenado por número de unidades vendidas por cliente
ps_top_buyers_units = pd_sales_multistore[['user_id', 'user_session']].groupby(['user_id']).count(). \
sort_values(by=['user_session'], ascending=False).rename(columns={'user_session': 'best_buyers_per_units_sold'}).head(10)
# Comando alternativo
# pd_sales_multistore.value_counts(subset=['user_id'])
ps_top_buyers_units
# Out:
#            best_buyers_per_units_sold
# user_id
# 568782581                        1974
# 549109608                        1342
# 513230794                        1340
# 513320236                        1141
# 598224683                         968
# 563599039                         921
# 553431815                         885
# 566448225                         826
# 628167977                         823
# 561174161                         804

# %%
# Evolución de las ventas (por unidades) a los clientes más compradores a lo largo del periodo observado: cliente nº 568782581
pd_sales_multistore_568782581 = pd_sales_multistore[pd_sales_multistore['user_id'] == 568782581].set_index('event_time')['user_session'] \
.resample('D').count().to_frame().reset_index()

fig, ax = plt.subplots(figsize=(18, 9))
ax.plot(pd_sales_multistore_568782581['event_time'],
        pd_sales_multistore_568782581['user_session'],
        '-o',
        color='purple')
ax.set(xlabel="Fecha", ylabel="Unidades compradas",
       title="Evolución de las unidades compradas por el usuario 568782581")

ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter("%d-%m-%y"))

plt.show()

# %%
# Evolución de las ventas (por unidades) a los clientes más compradores a lo largo del periodo observado: cliente nº 549109608
pd_sales_multistore_549109608 = pd_sales_multistore[pd_sales_multistore['user_id'] == 549109608].set_index('event_time')['user_session'] \
.resample('D').count().to_frame().reset_index()

fig, ax = plt.subplots(figsize=(18, 9))
ax.plot(pd_sales_multistore_549109608['event_time'],
        pd_sales_multistore_549109608['user_session'],
        '-o',
        color='orange')
ax.set(xlabel="Fecha", ylabel="Unidades compradas",
       title="Evolución de las unidades compradas por el usuario 549109608")

ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter("%d-%m-%y"))

plt.show()

# %% [markdown]
# ### 5.5 Clientes más compradores (por el importe de compra)

# %%
# Dataset ordenado por número de unidades vendidas por cliente
pd_sales_multistore[['user_id', 'price']].groupby(['user_id']).sum(). \
sort_values(by=['price'], ascending=False).rename(columns={'price': 'best_buyers_total_sale'}).head(10)
# Comando alternativo
# pd_sales_multistore.value_counts(subset=['user_id'])
# ps_top_buyers_value
# Out:
#           best_buyers_total_sale
# user_id
# 553431815              788315.95
# 549109608              727569.03
# 569333570              675298.33
# 513230794              631763.40
# 595104624              601099.77
# 513320236              559629.79
# 568782581              513424.50
# 538216048              496900.03
# 598224683              484483.11
# 512386086              472554.62

# %%
sns.set(font_scale=1.2)
# Evolución de las ventas (por importe) a los clientes más compradores a lo largo del periodo observado: cliente nº 553431815
pd_sales_multistore_553431815 = pd_sales_multistore[pd_sales_multistore['user_id'] == 553431815].set_index('event_time')['price'] \
.resample('D').sum().astype(float).to_frame().reset_index()

fig, ax = plt.subplots(figsize=(18, 9))
ax.plot(pd_sales_multistore_553431815['event_time'],
        pd_sales_multistore_553431815['price'],
        '-o',
        color='brown')
ax.set(xlabel="Fecha", ylabel="Unidades compradas",
       title="Evolución de la cifra de ventas realizadas al usuario 553431815",)
# fig.set(legend="Importe de venta")
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter("%d-%m-%y"))
plt.show()

# %% [markdown]
# ### 5.6 Días con más ventas

# %%
# Dataset con ventas en unidades agrupadas por día
pd_sales_multistore_total_units = pd_sales_multistore.set_index('event_time')['user_session'].resample('D'). \
count().sort_values(ascending=False).to_frame().rename(columns={'user_session': 'sales_on_a_day'})
pd_sales_multistore_total_units.head(10)
# Out:
#                            sales_on_a_day
# event_time
# 2019-11-17 00:00:00+00:00          134718
# 2020-02-12 00:00:00+00:00           69357
# 2020-02-16 00:00:00+00:00           57731
# 2019-12-16 00:00:00+00:00           55518
# 2020-02-13 00:00:00+00:00           55500
# 2019-11-16 00:00:00+00:00           51205
# 2020-02-14 00:00:00+00:00           50602
# 2020-02-15 00:00:00+00:00           48278
# 2020-03-02 00:00:00+00:00           47147
# 2019-12-30 00:00:00+00:00           45127

# %%
sns.set(rc={'axes.facecolor':'lightgrey'}, font_scale=1.2)

fig, ax = plt.subplots(figsize=(18, 9))
ax.scatter(pd_sales_multistore_total_units.index,
        pd_sales_multistore_total_units['sales_on_a_day'],
        s=3,
        marker='o',
        c=['red'])
# plt.yscale('log')
ax.set(xlabel="Fecha", ylabel="Unidades vendidas",
       title="Evolución de las ventas totales (en unidades) por día",)

ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter("%d-%m-%y"))
plt.show()

# %% [markdown]
# Llama la atención que haya varios días de febrero con máximos de ventas: 12/02/2020, 13/02/2020, 14/02/2020, 15/02/2020, 16/02/2020. He estado investigando en que país podría haber algún tipo de celebración o semana especial de rebajas y lo más cercano que he encontrado es la Fiesta de la Primavera (Año Nuevo) en China.

# %% [markdown]
# ### 5.7 "Customer behavior"

# %%
# Referencias compradas por el cliente más comprador durante una sesión
# Consulto primero la sesión en la que ha comprado más referencias
ps_customer_sales_553431815 = pd_sales_multistore[pd_sales_multistore['user_id'] == 553431815].groupby(['user_session']) \
['user_id'].count().to_frame().sort_values(by=['user_id'], ascending=False) \
.rename(columns={'user_id': 'bought_products'})
# .rename(columns={'user_session': 'best_buyers_per_units_sold'}).head(10)
ps_customer_sales_553431815
# Out:
#                                       bought_products
# user_session
# 75afc686-5967-4352-befe-378f7977abf4               46
# a504c379-9d7e-40e4-8979-e5ff42251714               27
# 9474ffd0-a87d-475b-9181-f90d830d4c80               24
# c04e8f89-1fa6-4c17-b185-e00e318c2a6f               19
# f1a88c8f-bafa-46ba-897f-603f73b4f338               18
# ...                                               ...
# 74374ad1-b22d-4660-9f73-0b2e0f8a3811                1
# 7486e466-8359-4bfe-a699-2e4a609f9695                1
# 762d75d4-6037-4bfb-becb-f09ac060ba42                1
# 77786869-0914-4e81-b163-5f683a6f5000                1
# ff49c3be-a509-4674-92fe-52f697d3d47e                1
#
# [250 rows x 1 columns]

# %%
# Probemos con la sesión n.º '75afc686-5967-4352-befe-378f7977abf4'.
ps_customer_behavior_553431815 = pd_sales_multistore[pd_sales_multistore['user_id'] == 553431815].reset_index()
ps_customer_behavior_553431815[ps_customer_behavior_553431815['user_session'] == '75afc686-5967-4352-befe-378f7977abf4'].sort_values(by='event_time')
# Out:
#        index                event_time  product_id          category_id  \
# 366  1610513 2019-12-16 19:10:19+00:00     1005107  2232732093077520756
# 367  1610536 2019-12-16 19:11:04+00:00     1005107  2232732093077520756
# 368  1610551 2019-12-16 19:11:41+00:00     1005107  2232732093077520756
# 369  1610575 2019-12-16 19:12:28+00:00     1005107  2232732093077520756
# 370  1610598 2019-12-16 19:13:12+00:00     1005107  2232732093077520756
# 371  1610634 2019-12-16 19:14:26+00:00     1005107  2232732093077520756
# 372  1610653 2019-12-16 19:15:01+00:00     1005107  2232732093077520756
# 373  1610668 2019-12-16 19:15:35+00:00     1005107  2232732093077520756
# 374  1610684 2019-12-16 19:16:21+00:00     1005107  2232732093077520756
# 375  1610708 2019-12-16 19:17:05+00:00     1005107  2232732093077520756
# 376  1610740 2019-12-16 19:18:00+00:00     1005107  2232732093077520756
# 377  1610760 2019-12-16 19:18:33+00:00     1005107  2232732093077520756
# 378  1610786 2019-12-16 19:19:13+00:00     1005107  2232732093077520756
# 379  1610809 2019-12-16 19:19:58+00:00     1005107  2232732093077520756
# 380  1610832 2019-12-16 19:20:49+00:00     1005107  2232732093077520756
# 381  1610934 2019-12-16 19:25:37+00:00     1005107  2232732093077520756
# 382  1610957 2019-12-16 19:26:29+00:00     1005107  2232732093077520756
# 383  1610971 2019-12-16 19:27:16+00:00     1005107  2232732093077520756
# 384  1610989 2019-12-16 19:28:07+00:00     1005107  2232732093077520756
# 385  1611007 2019-12-16 19:28:53+00:00     1005107  2232732093077520756
# 386  1611039 2019-12-16 19:30:10+00:00     1005107  2232732093077520756
# 387  1611085 2019-12-16 19:31:54+00:00     1005107  2232732093077520756
# 388  1611137 2019-12-16 19:33:48+00:00     1005107  2232732093077520756
# 389  1611157 2019-12-16 19:34:44+00:00     1005107  2232732093077520756
# 390  1611191 2019-12-16 19:35:50+00:00     1005107  2232732093077520756
# 391  1611220 2019-12-16 19:36:40+00:00     1005107  2232732093077520756
# 392  1611232 2019-12-16 19:37:25+00:00     1005107  2232732093077520756
# 393  1611246 2019-12-16 19:37:59+00:00     1005107  2232732093077520756
# 394  1611267 2019-12-16 19:38:45+00:00     1005107  2232732093077520756
# 395  1611285 2019-12-16 19:39:25+00:00     1005107  2232732093077520756
# 396  1611302 2019-12-16 19:40:07+00:00     1005107  2232732093077520756
# 397  1611322 2019-12-16 19:40:53+00:00     1005107  2232732093077520756
# 398  1611345 2019-12-16 19:41:43+00:00     1005107  2232732093077520756
# 399  1611360 2019-12-16 19:42:31+00:00     1005107  2232732093077520756
# 400  1611378 2019-12-16 19:43:15+00:00     1005107  2232732093077520756
# 401  1611410 2019-12-16 19:44:35+00:00     1005107  2232732093077520756
# 402  1611425 2019-12-16 19:45:23+00:00     1005107  2232732093077520756
# 403  1611438 2019-12-16 19:45:57+00:00     1005107  2232732093077520756
# 404  1611454 2019-12-16 19:46:31+00:00     1005107  2232732093077520756
# 405  1611468 2019-12-16 19:47:15+00:00     1005107  2232732093077520756
# 406  1611483 2019-12-16 19:47:54+00:00     1005107  2232732093077520756
# 407  1611497 2019-12-16 19:48:47+00:00     1005107  2232732093077520756
# 408  1611511 2019-12-16 19:49:27+00:00     1005107  2232732093077520756
# 409  1611519 2019-12-16 19:50:08+00:00     1005107  2232732093077520756
# 410  1611532 2019-12-16 19:50:58+00:00     1005107  2232732093077520756
# 411  1611545 2019-12-16 19:51:41+00:00     1005107  2232732093077520756
#
#                 category_code  brand    price    user_id  \
# 366  construction.tools.light  apple  1041.97  553431815
# 367  construction.tools.light  apple  1041.97  553431815
# 368  construction.tools.light  apple  1041.97  553431815
# 369  construction.tools.light  apple  1041.97  553431815
# 370  construction.tools.light  apple  1041.97  553431815
# 371  construction.tools.light  apple  1041.97  553431815
# 372  construction.tools.light  apple  1041.97  553431815
# 373  construction.tools.light  apple  1041.97  553431815
# 374  construction.tools.light  apple  1041.97  553431815
# 375  construction.tools.light  apple  1041.97  553431815
# 376  construction.tools.light  apple  1041.97  553431815
# 377  construction.tools.light  apple  1041.97  553431815
# 378  construction.tools.light  apple  1041.97  553431815
# 379  construction.tools.light  apple  1041.97  553431815
# 380  construction.tools.light  apple  1041.97  553431815
# 381  construction.tools.light  apple  1041.97  553431815
# 382  construction.tools.light  apple  1041.97  553431815
# 383  construction.tools.light  apple  1041.97  553431815
# 384  construction.tools.light  apple  1041.97  553431815
# 385  construction.tools.light  apple  1041.97  553431815
# 386  construction.tools.light  apple  1041.97  553431815
# 387  construction.tools.light  apple  1041.97  553431815
# 388  construction.tools.light  apple  1041.97  553431815
# 389  construction.tools.light  apple  1041.97  553431815
# 390  construction.tools.light  apple  1041.97  553431815
# 391  construction.tools.light  apple  1041.97  553431815
# 392  construction.tools.light  apple  1041.97  553431815
# 393  construction.tools.light  apple  1041.97  553431815
# 394  construction.tools.light  apple  1041.97  553431815
# 395  construction.tools.light  apple  1041.97  553431815
# 396  construction.tools.light  apple  1041.97  553431815
# 397  construction.tools.light  apple  1041.97  553431815
# 398  construction.tools.light  apple  1041.97  553431815
# 399  construction.tools.light  apple  1041.97  553431815
# 400  construction.tools.light  apple  1041.97  553431815
# 401  construction.tools.light  apple  1041.97  553431815
# 402  construction.tools.light  apple  1041.97  553431815
# 403  construction.tools.light  apple  1041.97  553431815
# 404  construction.tools.light  apple  1041.97  553431815
# 405  construction.tools.light  apple  1041.97  553431815
# 406  construction.tools.light  apple  1041.97  553431815
# 407  construction.tools.light  apple  1041.97  553431815
# 408  construction.tools.light  apple  1041.97  553431815
# 409  construction.tools.light  apple  1041.97  553431815
# 410  construction.tools.light  apple  1041.97  553431815
# 411  construction.tools.light  apple  1041.97  553431815
#
#                              user_session
# 366  75afc686-5967-4352-befe-378f7977abf4
# 367  75afc686-5967-4352-befe-378f7977abf4
# 368  75afc686-5967-4352-befe-378f7977abf4
# 369  75afc686-5967-4352-befe-378f7977abf4
# 370  75afc686-5967-4352-befe-378f7977abf4
# 371  75afc686-5967-4352-befe-378f7977abf4
# 372  75afc686-5967-4352-befe-378f7977abf4
# 373  75afc686-5967-4352-befe-378f7977abf4
# 374  75afc686-5967-4352-befe-378f7977abf4
# 375  75afc686-5967-4352-befe-378f7977abf4
# 376  75afc686-5967-4352-befe-378f7977abf4
# 377  75afc686-5967-4352-befe-378f7977abf4
# 378  75afc686-5967-4352-befe-378f7977abf4
# 379  75afc686-5967-4352-befe-378f7977abf4
# 380  75afc686-5967-4352-befe-378f7977abf4
# 381  75afc686-5967-4352-befe-378f7977abf4
# 382  75afc686-5967-4352-befe-378f7977abf4
# 383  75afc686-5967-4352-befe-378f7977abf4
# 384  75afc686-5967-4352-befe-378f7977abf4
# 385  75afc686-5967-4352-befe-378f7977abf4
# 386  75afc686-5967-4352-befe-378f7977abf4
# 387  75afc686-5967-4352-befe-378f7977abf4
# 388  75afc686-5967-4352-befe-378f7977abf4
# 389  75afc686-5967-4352-befe-378f7977abf4
# 390  75afc686-5967-4352-befe-378f7977abf4
# 391  75afc686-5967-4352-befe-378f7977abf4
# 392  75afc686-5967-4352-befe-378f7977abf4
# 393  75afc686-5967-4352-befe-378f7977abf4
# 394  75afc686-5967-4352-befe-378f7977abf4
# 395  75afc686-5967-4352-befe-378f7977abf4
# 396  75afc686-5967-4352-befe-378f7977abf4
# 397  75afc686-5967-4352-befe-378f7977abf4
# 398  75afc686-5967-4352-befe-378f7977abf4
# 399  75afc686-5967-4352-befe-378f7977abf4
# 400  75afc686-5967-4352-befe-378f7977abf4
# 401  75afc686-5967-4352-befe-378f7977abf4
# 402  75afc686-5967-4352-befe-378f7977abf4
# 403  75afc686-5967-4352-befe-378f7977abf4
# 404  75afc686-5967-4352-befe-378f7977abf4
# 405  75afc686-5967-4352-befe-378f7977abf4
# 406  75afc686-5967-4352-befe-378f7977abf4
# 407  75afc686-5967-4352-befe-378f7977abf4
# 408  75afc686-5967-4352-befe-378f7977abf4
# 409  75afc686-5967-4352-befe-378f7977abf4
# 410  75afc686-5967-4352-befe-378f7977abf4
# 411  75afc686-5967-4352-befe-378f7977abf4

# %% [markdown]
# Este ejemplo no permite deducir un patrón de compra del cliente, porque resulta que ha comprado **50 veces** la misma referencia en una misma sesión. Es bastante sospechoso, a menos que no se trate de un gran cliente que realiza compras masivas (algo, por otra parte, extraño en una web de e-commerce minorista).

# %% [markdown]
# ## 6. Categoría "Smartphones"

# %%
df_smartphones = pd_sales_multistore.loc[pd_sales_multistore['category_code'] == 'electronics.smartphone', ['event_time', 'product_id', 'brand', 'price', 'user_id', 'user_session']]

# %%
df_smartphones.head(10)
# Out:
#                   event_time  product_id    brand   price    user_id  \
# 0  2019-10-01 00:02:14+00:00     1004856  samsung  130.76  543272936
# 1  2019-10-01 00:04:37+00:00     1002532    apple  642.69  551377651
# 5  2019-10-01 00:10:08+00:00     1002524    apple  515.67  524325294
# 8  2019-10-01 00:14:14+00:00     1004932     vivo  463.31  555083442
# 9  2019-10-01 02:19:10+00:00     1004246    apple  736.18  515246296
# 10 2019-10-01 02:19:34+00:00     1005104    apple  975.57  555160488
# 14 2019-10-01 02:20:33+00:00     1003316    apple  946.97  516198933
# 15 2019-10-01 02:21:02+00:00     1004659  samsung  787.18  555168263
# 17 2019-10-01 02:22:11+00:00     1004750  samsung  197.43  555110488
# 21 2019-10-01 02:23:05+00:00     1004903   huawei  111.82  512812487
#
#                             user_session
# 0   8187d148-3c41-46d4-b0c0-9c08cd9dc564
# 1   3c80f0d6-e9ec-4181-8c5c-837a30be2d68
# 5   0b74a829-f9d7-4654-b5b0-35bc9822c238
# 8   83d12d1a-5452-4fa0-abbb-d9f492f8b562
# 9   b7dbae4f-cad3-463e-89ce-41990cf48dea
# 10  a1395546-c124-456c-9752-0f5cf883c63d
# 14  e1050ba4-5425-4b8e-9cc8-194878031718
# 15  d068d08f-aaf3-4949-b031-cdaf49a5c7cf
# 17  ce885079-4d92-4fe6-92a3-377c5a2d8291
# 21  d3ef047f-9476-4b8d-a126-b483c55de653

# %%
df_smartphones.shape
# Out:
# (733214, 6)

# %% [markdown]
# ### 6.1 Unidades vendidas de smartphones, por marca y referencia

# %%
df_smartphones_brands_products_count = df_smartphones.groupby(['brand', 'product_id'], observed=True)['user_session'] \
.count().to_frame().sort_values(by=['brand', 'user_session'], ascending=[True, False]) \
.rename(columns={'user_session': 'sales'})

# %%
df_smartphones_brands_products_count.head(15)
# Out:
#                    sales
# brand  product_id
# a-case 18001428       25
#        18001415        2
#        18001340        1
#        18001378        1
# apple  1005115     34785
#        1002544     22225
#        1004249     17970
#        1005105     15776
#        1002524     12877
#        1002633     10533
#        1005135      7502
#        1003306      7366
#        1005116      7036
#        1004258      5422
#        1003317      5254

# %% [markdown]
# La guardo como csv, porque puede servir para el futuro.

# %%
df_smartphones_brands_products_count.to_csv('df_smartphones_brands_products_count.csv')

# %% [markdown]
# ### 6.2 Lista de marcas (entre otras cosas para utilizarla en Google Trends)

# %%
df_smartphones_brands_products_count.index.unique(level='brand')
# Out:
# CategoricalIndex(['a-case', 'apple', 'asus', 'blackberry', 'bq', 'denzel',
#                   'deppa', 'doogee', 'fly', 'gionee', 'goodloot', 'google',
#                   'haier', 'hiper', 'honor', 'htc', 'huawei', 'inoi', 'irbis',
#                   'iwalk', 'jinga', 'karya', 'kisswill', 'lego', 'lenovo',
#                   'lg', 'meizu', 'micromax', 'nillkin', 'nokia', 'nubia',
#                   'oneplus', 'oppo', 'petek', 'philips', 'prestigio', 'rapid',
#                   'samsung', 'sony', 'takeit', 'tecno', 'texet', 'tp-link',
#                   'umi', 'vega', 'vertex', 'vivo', 'x-level', 'xiaomi', 'zte'],
#                  categories=['a-case', 'a-derma', 'a-elita', 'a-mega', 'a-toys', 'aardwolf', 'abaybooks', 'abc', ...], ordered=False, dtype='category', name='brand')

# %% [markdown]
# ### 6.3 Evolución de las ventas (por unidades) de una marca concreta

# %%
# Evolución de las ventas (por unidades) de una marca concreta a lo largo del periodo observado: marca Apple
pd_sales_multistore_apple = pd_sales_multistore[pd_sales_multistore['brand'] == 'apple'].set_index('event_time')['user_session'] \
.resample('D').count().to_frame().reset_index()

fig, ax = plt.subplots(figsize=(18, 9))
ax.plot(pd_sales_multistore_apple['event_time'],
        pd_sales_multistore_apple['user_session'],
        '-o',
        color='indianred')
ax.set(xlabel="Fecha", ylabel="Unidades vendidas",
       title="Evolución de las unidades vendidas de la marca Apple")

ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter("%d-%m-%y"))

plt.show()

# %% [markdown]
# ## X. Experimentos

# %%
# Agrego una columna con el número de unidades vendidas de la product_id
pd_sales_multistore['product_id_count'] = pd_sales_multistore['product_id'].map(pd_sales_multistore['product_id'].value_counts())

# %%
pd_sales_multistore.head()
# Out:
#                  event_time  product_id          category_id  \
# 0 2019-10-01 00:02:14+00:00     1004856  2053013555631882655
# 1 2019-10-01 00:04:37+00:00     1002532  2053013555631882655
# 2 2019-10-01 00:07:07+00:00    13800054  2053013557418656265
# 3 2019-10-01 00:09:26+00:00     4804055  2053013554658804075
# 4 2019-10-01 00:09:54+00:00     4804056  2053013554658804075
#
#                  category_code    brand   price    user_id  \
# 0       electronics.smartphone  samsung  130.76  543272936
# 1       electronics.smartphone    apple  642.69  551377651
# 2    furniture.bathroom.toilet  santeri   54.42  555332717
# 3  electronics.audio.headphone    apple  189.91  524601178
# 4  electronics.audio.headphone    apple  161.98  551377651
#
#                            user_session  product_id_count
# 0  8187d148-3c41-46d4-b0c0-9c08cd9dc564            137999
# 1  3c80f0d6-e9ec-4181-8c5c-837a30be2d68              5966
# 2  1dea3ee2-2ded-42e8-8e7a-4e2ad6ae942f                11
# 3  2af9b570-0942-4dcd-8f25-4d84fba82553             33183
# 4  3c80f0d6-e9ec-4181-8c5c-837a30be2d68            119640

# %%
pd_sales_multistore.sort_values(by=['product_id_count'], ascending=False)
# Out:
#                        event_time  product_id          category_id  \
# 553132  2019-11-01 06:30:49+00:00     1004767  2053013555631882655
# 3602435 2020-02-16 08:24:35+00:00     1004767  2232732093077520756
# 1798499 2019-12-21 10:02:34+00:00     1004767  2232732093077520756
# 1798496 2019-12-21 10:02:29+00:00     1004767  2232732093077520756
# 153726  2019-10-10 10:04:16+00:00     1004767  2053013555631882655
# ...                           ...         ...                  ...
# 2713873 2020-01-22 06:51:33+00:00   100059107  2053013566142809077
# 3154969 2020-02-08 14:41:47+00:00   100109296  2232732102858637897
# 5336784 2020-04-17 18:57:37+00:00    40500112  2232732100224614933
# 1531419 2019-12-15 06:02:09+00:00    34400002  2053013553853497655
# 1757918 2019-12-20 09:24:51+00:00     1307204  2053013558920217191
#
#                         category_code       brand    price    user_id  \
# 553132         electronics.smartphone     samsung   242.48  557907552
# 3602435      construction.tools.light     samsung   230.12  606699457
# 1798499      construction.tools.light     samsung   244.08  530278581
# 1798496      construction.tools.light     samsung   244.08  550347248
# 153726         electronics.smartphone     samsung   250.93  523291844
# ...                               ...         ...      ...        ...
# 2713873  construction.tools.generator        lara    24.78  516586482
# 3154969     furniture.bedroom.blanket      rieker    73.88  544932246
# 5336784       country_yard.cultivator        hoco     3.09  553485991
# 1531419                 apparel.jeans  leatherman   183.79  568397620
# 1757918            computers.notebook          hp  1055.11  530060658
#
#                                  user_session  product_id_count
# 553132   af212783-36e7-4286-8801-efcbe43a2c52            172598
# 3602435  cd415d2e-3ee6-4b9e-b8bf-effb4fec7ee9            172598
# 1798499  27acb7f7-c87a-4487-b8b9-8b145f7c650d            172598
# 1798496  029ad8c6-a035-4ecf-b0e5-e5fa0af4a46f            172598
# 153726   e73bccef-eaac-4391-9db4-99d4509913bd            172598
# ...                                       ...               ...
# 2713873  f74c1cf6-bdd7-4a64-8145-30b48b4f78a8                 1
# 3154969  9b507d78-667d-4982-bf46-a3a6823d74cc                 1
# 5336784  0fe279ed-17eb-4dbd-9734-6ba5f8e440fe                 1
# 1531419  0a2c3a68-3343-474c-b9fb-6b9894c3b30c                 1
# 1757918  0d6052d7-3a18-4752-ba32-29290a509ce6                 1
#
# [5573718 rows x 9 columns]

# %%
pd_sales_multistore_brands = pd.DataFrame({'Product ID': pd_sales_multistore['product_id'],
                                           'Brand': pd_sales_multistore['brand']},)

# %%
pd_sales_multistore_brands['Referencias vendidas'] = pd_sales_multistore_brands.groupby('Product ID', as_index=False).transform(lambda s: s.count())

# %%
pd_sales_multistore_brands.groupby('Product ID').head(10)
# Out:
#          Product ID      Brand  Referencias vendidas
# 0           1004856    samsung                139666
# 1           1002532      apple                  6043
# 2          13800054    santeri                    11
# 3           4804055      apple                 33990
# 4           4804056      apple                122056
# ...             ...        ...                   ...
# 5707888    15800011    karcher                    29
# 5707910   100216253  decathlon                     6
# 5707911     4200997    almacom                    38
# 5707912     4802522      remax                     2
# 5707914   100189373     stayer                     5
#
# [1176282 rows x 3 columns]

# %%
# Equivalente a 
# pd_sales_multistore.value_counts(subset=['product_id'])
# If you have any categorical columns in your data (rather than categories stored as object columns or strings),
# make sure you use the observed=True option in your groupby command.
# This makes sure it only creates lines where an entry is present, e.g. only one line per customer_id,order_id combination,
# rather than creating n_custs * n_orders lines!
df_brands_products_count = pd_sales_multistore.groupby(['brand', 'product_id'], observed=True)['user_session'].count().to_frame()

# %%
df_brands_products_count.sort_values(by=['brand', 'user_session'], ascending=[True, False], inplace=True)

# %%
df_brands_products_count
# Out:
#                    user_session
# brand  product_id
# a-case 100014125            342
#        100014007            231
#        100118021            164
#        100118024            134
#        18001338             128
# ...                         ...
# zvezda 100023890              1
# zyxel  7600021                2
#        7600096                1
#        7600139                1
#        7600559                1
#
# [96722 rows x 1 columns]

# %% [markdown]
# ## X. read_csv modificado para convertir directamente los tipos de las columnas

# %%
pd_sales_multistore = pd.read_csv('sales_multistore_10_2019_04_2020_v2.csv',
                 dtype={'product_id':'int32', 'category_id':'int64'}, 
                 converters={'price': D.Decimal})

# %% [markdown]
# ## Dask - Una librería para hacer computaciones en paralelo
#
# import dask.dataframe as dd
#
# df = dd.from_pandas(df)
#
# result = df.groupby('id').max().reset_index().compute()
#
# All you need to do is convert your pandas.DataFrame into a dask.dataframe. Dask is a python out-of-core parallelization framework that offers various parallelized container types, one of which is the dataframe. It let's you perform most common pandas.DataFrame operations in parallel and/or distributed with data that is too large to fit in memory. The core of dask is a set of schedulers and an API for building computation graphs, hence we have to call .compute() at the end in order for any computation to actually take place. The library is easy to install because it is written in pure python for the most part.
