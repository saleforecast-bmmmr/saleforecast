# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline

cm = plt.cm.RdBu
cm_bright = ListedColormap(['#FF0000', '#0000FF'])

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', None) # para mostrar todas las filas
pd.set_option('display.max_columns', None) # para mostrar todas las columnas

# %%
df_jan =  pd.read_csv('./2020-Jan.csv', sep=',',decimal='.')

# %%
df_jan.head().T
# Out:
#                                                   0  \
# event_time                  2020-01-01 00:00:00 UTC
# event_type                                     view
# product_id                                  1005073
# category_id                     2232732093077520756
# category_code              construction.tools.light
# brand                                       samsung
# price                                       1130.02
# user_id                                   519698804
# user_session   69b5d72f-fd6e-4fed-aa23-1286b2ca89a0
#
#                                                   1  \
# event_time                  2020-01-01 00:00:01 UTC
# event_type                                     view
# product_id                                  1005192
# category_id                     2232732093077520756
# category_code              construction.tools.light
# brand                                         meizu
# price                                        205.67
# user_id                                   527767423
# user_session   7f596032-ccbf-4643-9bad-e36a209512b4
#
#                                                   2  \
# event_time                  2020-01-01 00:00:01 UTC
# event_type                                     view
# product_id                                100063693
# category_id                     2053013552427434207
# category_code                         apparel.shirt
# brand                                        turtle
# price                                        136.43
# user_id                                   519046195
# user_session   d1e2f343-84bb-49bd-b13d-ca0f1ed9910e
#
#                                                   3  \
# event_time                  2020-01-01 00:00:01 UTC
# event_type                                     view
# product_id                                  5100816
# category_id                     2232732103831716449
# category_code                         apparel.shoes
# brand                                        xiaomi
# price                                         29.95
# user_id                                   518269232
# user_session   0444841c-38ef-410c-b11f-7b35ea4e5991
#
#                                                   4
# event_time                  2020-01-01 00:00:02 UTC
# event_type                                     view
# product_id                                100014325
# category_id                     2232732103294845523
# category_code                apparel.shoes.step_ins
# brand                                         intel
# price                                         167.2
# user_id                                   587748686
# user_session   31b7d4cf-dfac-4895-9927-90fa3254f860

# %%
df_jan.apply(lambda x: len(x.unique()))
# Out:
# event_time        2641539
# event_type              3
# product_id         227608
# category_id          1201
# category_code         136
# brand                5084
# price               73596
# user_id           4385985
# user_session     13847855
# dtype: int64

# %%
## Creo que se debe eliminar la columna de user_session ya que solo parece ser un id de la sesion.
## Se nota la diferencia entre user_id y user_session.

# %%
## No se entiende por que existen mas category_id que category_code, en que se diferencian?
##product_id tampoco nos identifica ningun producto especifico parece algo interno de la tienda

# %%
drop_columns = ['user_session', 'category_id', 'product_id']

# %%
df_jan.drop(drop_columns, axis=1, inplace=True)

# %%
df_jan.head().T
# Out:
#                                       0                         1  \
# event_time      2020-01-01 00:00:00 UTC   2020-01-01 00:00:01 UTC
# event_type                         view                      view
# category_code  construction.tools.light  construction.tools.light
# brand                           samsung                     meizu
# price                           1130.02                    205.67
# user_id                       519698804                 527767423
#
#                                      2                        3  \
# event_time     2020-01-01 00:00:01 UTC  2020-01-01 00:00:01 UTC
# event_type                        view                     view
# category_code            apparel.shirt            apparel.shoes
# brand                           turtle                   xiaomi
# price                           136.43                    29.95
# user_id                      519046195                518269232
#
#                                      4
# event_time     2020-01-01 00:00:02 UTC
# event_type                        view
# category_code   apparel.shoes.step_ins
# brand                            intel
# price                            167.2
# user_id                      587748686

# %%
df_jan_el = df_jan.loc[df_jan.category_code == 'electronics.smartphone']

# %%
print(f'El dataframe tiene un total de {len(df_jan_el)} filas.')
len(df_jan_el) - df_jan_el.count() # vemos cuántos valores NaN hay por columna
# Out:
# El dataframe tiene un total de 446779 filas.
# event_time          0
# event_type          0
# category_code       0
# brand            2024
# price               0
# user_id             0
# dtype: int64

# %%
df_jan_el['brand'].unique()
# Out:
# array(['huawei', 'lg', 'xiaomi', 'samsung', 'apple', nan, 'deppa', 'oppo',
#        'karya', 'nokia', 'honor', 'remax', 'sony', 'prestigio', 'hiper',
#        'meizu', 'bq', 'haier', 'x-level', 'vivo', 'doogee', 'vega',
#        'a-case', 'usams', 'irbis', 'google', 'nillkin', 'fini', 'vertex',
#        'asus', 'tecno', 'oneplus', 'takeit', 'moshi', 'texet', 'tp-link',
#        'dub', 'mujjo', 'petek', 'goodloot', 'jinga', 'gionee', 'lego',
#        'yotrix', 'motorola', 'zte', 'inoi', 'blackberry', 'blackview',
#        'htc', 'iwalk', 'fly', 'hoco', 'micromax', 'toto', 'janesper',
#        'rapid', 'kajsa', 'denzel', 'fubag', 'ark', 'rivacase', 'wuw',
#        'ubear', 'keneksi'], dtype=object)

# %%
df_jan_clean = df_jan_el.dropna()

# %%
df_jan_clean.head().T
# Out:
#                                    22                       48   \
# event_time     2020-01-01 00:00:05 UTC  2020-01-01 00:00:12 UTC
# event_type                        view                     view
# category_code   electronics.smartphone   electronics.smartphone
# brand                           huawei                       lg
# price                            149.3                    205.9
# user_id                      517014550                536578949
#
#                                    148                      197  \
# event_time     2020-01-01 00:00:41 UTC  2020-01-01 00:00:55 UTC
# event_type                        view                     view
# category_code   electronics.smartphone   electronics.smartphone
# brand                           xiaomi                   xiaomi
# price                           192.26                   192.26
# user_id                      532166853                532166853
#
#                                    325
# event_time     2020-01-01 00:01:32 UTC
# event_type                        view
# category_code   electronics.smartphone
# brand                               lg
# price                            205.9
# user_id                      536578949

# %%
#creo que se debe codificar las categorias y las marcas para poder realizar una matriz correlacion mas clara
#y poder ubicar mas claramente los outlayers

# %%
dummies_event = pd.get_dummies(df_jan_clean.event_type)
dummies_brand = pd.get_dummies(df_jan_clean.brand)

# %%
df_dummies = pd.concat([df_jan_clean, dummies_event, dummies_brand], axis='columns')
df_dummies.drop(['event_type', 'brand'], axis=1, inplace=True)

# %%
df_dummies.head().T
# Out:
#                                    22                       48   \
# event_time     2020-01-01 00:00:05 UTC  2020-01-01 00:00:12 UTC
# category_code   electronics.smartphone   electronics.smartphone
# price                            149.3                    205.9
# user_id                      517014550                536578949
# cart                                 0                        0
# purchase                             0                        0
# view                                 1                        1
# a-case                               0                        0
# apple                                0                        0
# ark                                  0                        0
# asus                                 0                        0
# blackberry                           0                        0
# blackview                            0                        0
# bq                                   0                        0
# denzel                               0                        0
# deppa                                0                        0
# doogee                               0                        0
# dub                                  0                        0
# fini                                 0                        0
# fly                                  0                        0
# fubag                                0                        0
# gionee                               0                        0
# goodloot                             0                        0
# google                               0                        0
# haier                                0                        0
# hiper                                0                        0
# hoco                                 0                        0
# honor                                0                        0
# htc                                  0                        0
# huawei                               1                        0
# inoi                                 0                        0
# irbis                                0                        0
# iwalk                                0                        0
# janesper                             0                        0
# jinga                                0                        0
# kajsa                                0                        0
# karya                                0                        0
# keneksi                              0                        0
# lego                                 0                        0
# lg                                   0                        1
# meizu                                0                        0
# micromax                             0                        0
# moshi                                0                        0
# motorola                             0                        0
# mujjo                                0                        0
# nillkin                              0                        0
# nokia                                0                        0
# oneplus                              0                        0
# oppo                                 0                        0
# petek                                0                        0
# prestigio                            0                        0
# rapid                                0                        0
# remax                                0                        0
# rivacase                             0                        0
# samsung                              0                        0
# sony                                 0                        0
