# %%
import pandas as pd
import matplotlib.pyplot as plt

#df_i =  pd.read_csv("tend_iphone_30paises.csv")
#df_s =  pd.read_csv("tend_samsung_30paises.csv")
#df_x =  pd.read_csv("tend_xiaomi_30paises.csv")
#df_1 = pd.merge(df_i, df_s, on=["geoName"])
#df_merged =  pd.merge(df_1, df_x, on=["geoName"])
#df_merged = df_merged.set_index('geoName')
df_merged = pd.read_csv("comparacion_smartphone.csv")
df_merged = df_merged.set_index('geoName')
df_merged.plot.bar(figsize=(20,8), color={"smartphone iphone": "#54bebe", "smartphone samsung": "#e4bcad", "smartphone xiaomi": "#c80064"})
# Out:
# <AxesSubplot:xlabel='geoName'>
