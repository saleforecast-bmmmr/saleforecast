# %%
#!pip install neuralprophet[live]
#!pip install pandas
#!pip install pytrends

# %%
from pytrends.request import TrendReq
import pandas as pd
import time
startTime = time.time()
pytrends = TrendReq(hl='en-GB', tz=360)

df =  pd.read_csv("datos/datos.csv")
df = df[['brand']]
df = df.drop_duplicates()
#keywords = df['brand']
keywords = ['apple','samsung','smartphone']
pytrends.build_payload(keywords, cat=0, timeframe="2019-10-01 2020-10-01", geo="ES")

df_pytrends = pytrends.interest_over_time()
df_pytrends = df_pytrends.drop(labels=['isPartial'],axis='columns')
df_pytrends.to_csv('search_trends.csv')
df_pytrends_historical =  pytrends.get_historical_interest(keywords)
df_pytrends_historical = df_pytrends_historical.drop(labels=['isPartial'],axis='columns')
df_pytrends_historical.to_csv('historical_trend.csv')
# Out:
# C:\Users\Jose Rodriguez\AppData\Local\Programs\Python\Python310\lib\site-packages\pytrends\request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# C:\Users\Jose Rodriguez\AppData\Local\Programs\Python\Python310\lib\site-packages\pytrends\request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# C:\Users\Jose Rodriguez\AppData\Local\Programs\Python\Python310\lib\site-packages\pytrends\request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# C:\Users\Jose Rodriguez\AppData\Local\Programs\Python\Python310\lib\site-packages\pytrends\request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# C:\Users\Jose Rodriguez\AppData\Local\Programs\Python\Python310\lib\site-packages\pytrends\request.py:611: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)

# %%
from neuralprophet import NeuralProphet
import matplotlib.pyplot as plt
from neuralprophet import set_random_seed 
set_random_seed(0)
# Out:
# WARNING - (py.warnings._showwarnmsg) - C:\Users\Jose Rodriguez\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\random.py:42: UserWarning: Failed to initialize NumPy: module compiled against API version 0x10 but this version of numpy is 0xf (Triggered internally at  ..\torch\csrc\utils\tensor_numpy.cpp:68.)
#   return default_generator.manual_seed(seed)

# %%
df_pytrends.plot(figsize=(14,9))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# Transformando el dataset para el modelo

# %%
df_pytrends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 52 entries, 2019-10-06 to 2020-09-27
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   apple       52 non-null     int32
#  1   samsung     52 non-null     int32
#  2   smartphone  52 non-null     int32
# dtypes: int32(3)
# memory usage: 1.0 KB

# %%
df_pytrends['date'] = df_pytrends.index

# %%
FORECAST_WEEKS = 48
TARGET_TERM = 'apple'

##df_neural = df_pytrends.rename(columns={'date': 'ds', TARGET_TERM: 'y'})[['ds', 'y']]
df_neural = df_pytrends.rename(columns = {'date': 'ds', TARGET_TERM:'y'})[['ds', 'y']]
df_neural.head()
# Out:
#                    ds   y
# date
# 2019-10-06 2019-10-06  34
# 2019-10-13 2019-10-13  30
# 2019-10-20 2019-10-20  31
# 2019-10-27 2019-10-27  33
# 2019-11-03 2019-11-03  33

# %%
import numpy as np

# %%
model = NeuralProphet(weekly_seasonality=True)
metrics = model.fit(df_neural, freq="W")
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency W-SUN corresponds to 98.077% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - W
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 model = NeuralProphet(weekly_seasonality=True)
# ----> 2 metrics = model.fit(df_neural, freq="W")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neuralprophet\forecaster.py:592, in NeuralProphet.fit(self, df, freq, validation_df, progress, minimal)
#     590         metrics_df = None
#     591     else:
# --> 592         metrics_df = self._train(df_dict, progress=progress)
#     593 else:
#     594     df_val_dict, _ = df_utils.prep_copy_df_dict(validation_df)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neuralprophet\forecaster.py:1806, in NeuralProphet._train(self, df_dict, df_val_dict, progress)
#    1803     return self._train_minimal(df_dict, progress_bar=progress_bar)
#    1805 # set up data loader
# -> 1806 loader = self._init_train_loader(df_dict)
#    1807 # set up Metrics
#    1808 if self.highlight_forecast_step_n is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neuralprophet\forecaster.py:1595, in NeuralProphet._init_train_loader(self, df_dict)
#    1592 if self.country_holidays_config is not None:
#    1593     self.country_holidays_config.init_holidays(df_merged)
# -> 1595 dataset = self._create_dataset(df_dict, predict_mode=False)  # needs to be called after set_auto_seasonalities
#    1596 self.config_train.set_auto_batch_epoch(n_data=len(dataset))
#    1598 loader = DataLoader(dataset, batch_size=self.config_train.batch_size, shuffle=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neuralprophet\forecaster.py:1276, in NeuralProphet._create_dataset(self, df_dict, predict_mode)
#    1252 def _create_dataset(self, df_dict, predict_mode):
#    1253     """Construct dataset from dataframe.
#    1254
#    1255     (Configured Hyperparameters can be overridden by explicitly supplying them.
#    (...)
#    1274         TimeDataset
#    1275     """
# -> 1276     return time_dataset.GlobalTimeDataset(
#    1277         df_dict,
#    1278         predict_mode=predict_mode,
#    1279         n_lags=self.n_lags,
#    1280         n_forecasts=self.n_forecasts,
#    1281         season_config=self.season_config,
#    1282         events_config=self.events_config,
#    1283         country_holidays_config=self.country_holidays_config,
#    1284         covar_config=self.config_covar,
#    1285         regressors_config=self.regressors_config,
#    1286     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neuralprophet\time_dataset.py:31, in GlobalTimeDataset.__init__(self, df_dict, **kwargs)
#      29 self.length = 0
#      30 for df_name, df in df_dict.items():
# ---> 31     timedataset = TimeDataset(df, df_name, **kwargs)
#      32     self.length += timedataset.length
#      33     for i in range(0, len(timedataset)):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neuralprophet\time_dataset.py:65, in TimeDataset.__init__(self, df, name, **kwargs)
#      63 self.two_level_inputs = ["seasonalities", "covariates"]
#      64 inputs, targets = tabularize_univariate_datetime(df, **kwargs)
# ---> 65 self.init_after_tabularized(inputs, targets)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neuralprophet\time_dataset.py:95, in TimeDataset.init_after_tabularized(self, inputs, targets)
#      93             self.inputs[key][name] = torch.from_numpy(features).type(inputs_dtype[key])
#      94     else:
# ---> 95         self.inputs[key] = torch.from_numpy(data).type(inputs_dtype[key])
#      96 self.targets = torch.from_numpy(targets).type(targets_dtype)
#      97 self.meta["df_name"] = self.name
#
# RuntimeError: Numpy is not available

# %%
future = model.make_future_dataframe(data, periods=FORECAST_WEEKS, n_historic_predictions=True)
future.head()

# %%
forecast = model.predict(future)

# %%
ax = model.plot(forecast, ylabel='Google Searches', xlabel='Year', figsize=(14,9))
